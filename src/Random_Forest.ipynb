# %%
# To upload the json file, choose the file below
from google.colab import files
files.upload()

# To load the kaggle Dataset
# Please Upload the kaggle.json file to the current directory
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# Downloading and unzipping dataset
! mkdir traffic_dataset
! kaggle datasets download -d silicon99/dft-accident-data
! unzip dft-accident-data.zip -d traffic_dataset/

# %%
# Cell for all the import statements

import pandas as pd
import matplotlib.pyplot as plt
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import seaborn

# Suppressing warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Reading the input file
accidents_file = pd.read_csv('traffic_dataset/Accidents0515.csv')

# Printing head of the file
accidents_file.head()
# Out:
#   Accident_Index  ...  LSOA_of_Accident_Location
# 0  200501BS00001  ...                  E01002849
# 1  200501BS00002  ...                  E01002909
# 2  200501BS00003  ...                  E01002857
# 3  200501BS00004  ...                  E01002840
# 4  200501BS00005  ...                  E01002863
#
# [5 rows x 32 columns]

# %%
# Removing the missing values
accidents_file.dropna(inplace=True)

# Preparing data for classification
x_values = accidents_file.drop('Accident_Severity', axis = 1)
x_values = x_values[['Longitude', 'Latitude', '1st_Road_Class', 'Day_of_Week', 'Light_Conditions', 'Weather_Conditions', 'Speed_limit', 'Number_of_Vehicles', 'Road_Surface_Conditions']]
y_values = accidents_file['Accident_Severity']
X_train, X_test, y_train, y_test = train_test_split(x_values, y_values, test_size = 0.20)

# Random Forest classifier with all the features
classifier = RandomForestClassifier(n_estimators = 100)
classifier.fit(X_train, y_train)

# Computing the predictions of the classifier
y_pred = classifier.predict(X_test)
print('Accuracy :', classifier.score(X_test, y_test) * 100)
print(classification_report(y_true = y_test, y_pred = y_pred))
# Out:
# Accuracy : 82.94819655451218
#               precision    recall  f1-score   support
#
#            1       0.05      0.01      0.01      4104
#            2       0.20      0.06      0.09     44020
#            3       0.86      0.96      0.91    282105
#
#     accuracy                           0.83    330229
#    macro avg       0.37      0.34      0.34    330229
# weighted avg       0.76      0.83      0.79    330229

# %%
# Removing the missing values
accidents_file.dropna(inplace=True)

# Preparing data for classification
x_values = accidents_file.drop('Weather_Conditions', axis = 1)
x_values = x_values[['Longitude', 'Latitude', '1st_Road_Class', 'Day_of_Week', 'Light_Conditions', 'Speed_limit', 'Number_of_Vehicles', 'Road_Surface_Conditions']]
y_values = accidents_file['Weather_Conditions']
X_train, X_test, y_train, y_test = train_test_split(x_values, y_values, test_size = 0.20)

# Random Forest classifier with all the features
classifier = RandomForestClassifier(n_estimators = 50)
classifier.fit(X_train, y_train)

# Computing the predictions of the classifier
y_pred = classifier.predict(X_test)
print('Accuracy :', classifier.score(X_test, y_test) * 100)
print(classification_report(y_true = y_test, y_pred = y_pred))
# Out:
# Accuracy : 80.02022838696783
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00        39
#            1       0.87      0.92      0.90    265659
#            2       0.44      0.45      0.44     37799
#            3       0.57      0.51      0.54      2150
#            4       0.02      0.00      0.01      4215
#            5       0.09      0.04      0.05      4480
#            6       0.12      0.04      0.06       323
#            7       0.04      0.01      0.01      1838
#            8       0.14      0.05      0.08      7198
#            9       0.33      0.09      0.14      6528
#
#     accuracy                           0.80    330229
#    macro avg       0.26      0.21      0.22    330229
# weighted avg       0.76      0.80      0.78    330229
